# %%
import pandas as pd
import numpy as np
import json

# %%
SOURCE_DATA_FP = '../../data/Healthcare Associated Infections - Hospital.csv'
hospital_df = pd.read_csv(SOURCE_DATA_FP)

# %%
hospital_df.columns = ['facility_id', 'facility_name', 'address',
                       'city', 'state', 'zip', 'county', 'phone_number',
                       'measure_id', 'measure_name', 'compared_to_national',
                       'score', 'footnote', 'start_date', 'end_date']

# %%
truth_table = hospital_df.groupby(['state', 'measure_id']).count().reset_index().sort_values('facility_id', ascending=False)

# %%
truth_table[truth_table['state'] == 'AK']
# Out:
#    state       measure_id  facility_id  facility_name  address  city  zip  \
# 0     AK    HAI_1_CILOWER           23             23       23    23   23
# 1     AK    HAI_1_CIUPPER           23             23       23    23   23
# 27    AK  HAI_5_ELIGCASES           23             23       23    23   23
# 21    AK  HAI_4_ELIGCASES           23             23       23    23   23
# 22    AK  HAI_4_NUMERATOR           23             23       23    23   23
# 23    AK        HAI_4_SIR           23             23       23    23   23
# 24    AK    HAI_5_CILOWER           23             23       23    23   23
# 25    AK    HAI_5_CIUPPER           23             23       23    23   23
# 26    AK       HAI_5_DOPC           23             23       23    23   23
# 28    AK  HAI_5_NUMERATOR           23             23       23    23   23
# 19    AK    HAI_4_CIUPPER           23             23       23    23   23
# 29    AK        HAI_5_SIR           23             23       23    23   23
# 30    AK    HAI_6_CILOWER           23             23       23    23   23
# 31    AK    HAI_6_CIUPPER           23             23       23    23   23
# 32    AK       HAI_6_DOPC           23             23       23    23   23
# 33    AK  HAI_6_ELIGCASES           23             23       23    23   23
# 34    AK  HAI_6_NUMERATOR           23             23       23    23   23
# 20    AK       HAI_4_DOPC           23             23       23    23   23
# 18    AK    HAI_4_CILOWER           23             23       23    23   23
# 9     AK  HAI_2_ELIGCASES           23             23       23    23   23
# 17    AK        HAI_3_SIR           23             23       23    23   23
# 2     AK       HAI_1_DOPC           23             23       23    23   23
# 3     AK  HAI_1_ELIGCASES           23             23       23    23   23
# 4     AK  HAI_1_NUMERATOR           23             23       23    23   23
# 5     AK        HAI_1_SIR           23             23       23    23   23
# 6     AK    HAI_2_CILOWER           23             23       23    23   23
# 7     AK    HAI_2_CIUPPER           23             23       23    23   23
# 8     AK       HAI_2_DOPC           23             23       23    23   23
# 35    AK        HAI_6_SIR           23             23       23    23   23
# 10    AK  HAI_2_NUMERATOR           23             23       23    23   23
# 11    AK        HAI_2_SIR           23             23       23    23   23
# 12    AK    HAI_3_CILOWER           23             23       23    23   23
# 13    AK    HAI_3_CIUPPER           23             23       23    23   23
# 14    AK       HAI_3_DOPC           23             23       23    23   23
# 15    AK  HAI_3_ELIGCASES           23             23       23    23   23
# 16    AK  HAI_3_NUMERATOR           23             23       23    23   23
#
#     county  phone_number  measure_name  compared_to_national  score  footnote  \
# 0       23            23            23                    23     23        23
# 1       23            23            23                    23     23        23
# 27      23            23            23                    23     23        23
# 21      23            23            23                    23     23        23
# 22      23            23            23                    23     23        23
# 23      23            23            23                    23     23        23
# 24      23            23            23                    23     23        23
# 25      23            23            23                    23     23        23
# 26      23            23            23                    23     23        23
# 28      23            23            23                    23     23        23
# 19      23            23            23                    23     23        23
# 29      23            23            23                    23     23        23
# 30      23            23            23                    23     23        23
# 31      23            23            23                    23     23        23
# 32      23            23            23                    23     23        23
# 33      23            23            23                    23     23        23
# 34      23            23            23                    23     23        23
# 20      23            23            23                    23     23        23
# 18      23            23            23                    23     23        23
# 9       23            23            23                    23     23        23
# 17      23            23            23                    23     23        23
# 2       23            23            23                    23     23        23
# 3       23            23            23                    23     23        23
# 4       23            23            23                    23     23        23
# 5       23            23            23                    23     23        23
# 6       23            23            23                    23     23        23
# 7       23            23            23                    23     23        23
# 8       23            23            23                    23     23        23
# 35      23            23            23                    23     23        23
# 10      23            23            23                    23     23        23
# 11      23            23            23                    23     23        23
# 12      23            23            23                    23     23        23
# 13      23            23            23                    23     23        23
# 14      23            23            23                    23     23        23
# 15      23            23            23                    23     23        23
# 16      23            23            23                    23     23        23
#
#     start_date  end_date
# 0           23        23
# 1           23        23
# 27          23        23
# 21          23        23
# 22          23        23
# 23          23        23
# 24          23        23
# 25          23        23
# 26          23        23
# 28          23        23
# 19          23        23
# 29          23        23
# 30          23        23
# 31          23        23
# 32          23        23
# 33          23        23
# 34          23        23
# 20          23        23
# 18          23        23
# 9           23        23
# 17          23        23
# 2           23        23
# 3           23        23
# 4           23        23
# 5           23        23
# 6           23        23
# 7           23        23
# 8           23        23
# 35          23        23
# 10          23        23
# 11          23        23
# 12          23        23
# 13          23        23
# 14          23        23
# 15          23        23
# 16          23        23

# %%
hospital_df[hospital_df['state'] == 'MA']
# Out:
#       facility_id                                  facility_name  \
# 72216      220001                  HEALTHALLIANCE HOSPITALS, INC
# 72217      220001                  HEALTHALLIANCE HOSPITALS, INC
# 72218      220001                  HEALTHALLIANCE HOSPITALS, INC
# 72219      220001                  HEALTHALLIANCE HOSPITALS, INC
# 72220      220001                  HEALTHALLIANCE HOSPITALS, INC
# ...           ...                                            ...
# 74551      223304  SHRINERS' HOSPITAL FOR CHILDREN - BOSTON, THE
# 74552      223304  SHRINERS' HOSPITAL FOR CHILDREN - BOSTON, THE
# 74553      223304  SHRINERS' HOSPITAL FOR CHILDREN - BOSTON, THE
# 74554      223304  SHRINERS' HOSPITAL FOR CHILDREN - BOSTON, THE
# 74555      223304  SHRINERS' HOSPITAL FOR CHILDREN - BOSTON, THE
#
#                  address        city state   zip     county    phone_number  \
# 72216   60 HOSPITAL ROAD  LEOMINSTER    MA  1453  WORCESTER  (978) 466-2000
# 72217   60 HOSPITAL ROAD  LEOMINSTER    MA  1453  WORCESTER  (978) 466-2000
# 72218   60 HOSPITAL ROAD  LEOMINSTER    MA  1453  WORCESTER  (978) 466-2000
# 72219   60 HOSPITAL ROAD  LEOMINSTER    MA  1453  WORCESTER  (978) 466-2000
# 72220   60 HOSPITAL ROAD  LEOMINSTER    MA  1453  WORCESTER  (978) 466-2000
# ...                  ...         ...   ...   ...        ...             ...
# 74551  51 BLOSSOM STREET      BOSTON    MA  2114    SUFFOLK  (617) 722-3000
# 74552  51 BLOSSOM STREET      BOSTON    MA  2114    SUFFOLK  (617) 722-3000
# 74553  51 BLOSSOM STREET      BOSTON    MA  2114    SUFFOLK  (617) 722-3000
# 74554  51 BLOSSOM STREET      BOSTON    MA  2114    SUFFOLK  (617) 722-3000
# 74555  51 BLOSSOM STREET      BOSTON    MA  2114    SUFFOLK  (617) 722-3000
#
#             measure_id                                       measure_name  \
# 72216    HAI_1_CILOWER  Central Line Associated Bloodstream Infection ...
# 72217    HAI_1_CIUPPER  Central Line Associated Bloodstream Infection ...
# 72218       HAI_1_DOPC  Central Line Associated Bloodstream Infection:...
# 72219  HAI_1_ELIGCASES  Central Line Associated Bloodstream Infection ...
# 72220  HAI_1_NUMERATOR  Central Line Associated Bloodstream Infection ...
# ...                ...                                                ...
# 74551    HAI_6_CIUPPER  Clostridium Difficile (C.Diff): Upper Confiden...
# 74552       HAI_6_DOPC       Clostridium Difficile (C.Diff): Patient Days
# 74553  HAI_6_ELIGCASES    Clostridium Difficile (C.Diff): Predicted Cases
# 74554  HAI_6_NUMERATOR     Clostridium Difficile (C.Diff): Observed Cases
# 74555        HAI_6_SIR                     Clostridium Difficile (C.Diff)
#
#                        compared_to_national          score footnote  \
# 72216  No Different than National Benchmark             --        8
# 72217  No Different than National Benchmark          1.294     null
# 72218  No Different than National Benchmark           2866     null
# 72219  No Different than National Benchmark          2.315     null
# 72220  No Different than National Benchmark              0     null
# ...                                     ...            ...      ...
# 74551                         Not Available  Not Available       19
# 74552                         Not Available  Not Available       19
# 74553                         Not Available  Not Available       19
# 74554                         Not Available  Not Available       19
# 74555                         Not Available  Not Available       19
#
#        start_date    end_date
# 72216  10/01/2018  09/30/2019
# 72217  10/01/2018  09/30/2019
# 72218  10/01/2018  09/30/2019
# 72219  10/01/2018  09/30/2019
# 72220  10/01/2018  09/30/2019
# ...           ...         ...
# 74551  10/01/2018  09/30/2019
# 74552  10/01/2018  09/30/2019
# 74553  10/01/2018  09/30/2019
# 74554  10/01/2018  09/30/2019
# 74555  10/01/2018  09/30/2019
#
# [2340 rows x 15 columns]

# %%
hospital_df = hospital_df.fillna('null')

# %%
hospital_dict = hospital_df.to_dict('records')

# %%
ES_DATA_FP = '../../es-index/documents.json'
with open(ES_DATA_FP, 'w') as f:
    for i, item in enumerate(hospital_dict):
        # remove missing scores
        if item['score'] in ['Not Available', '--']:
            item.pop('score')
        head = {"create": {"_index": "hospital-index"}}
        doc = '{}\n{}\n'.format(json.dumps(head), json.dumps(item))
        f.write(doc)
#         if i == 100:
#             break
    f.write('\n')

# %%
for i, item in enumerate(hospital_dict):
    head = {"_index": "hospital-index",
            "_id": str(i)}
    doc = '{}\n{}\n'.format(json.dumps(head), json.dumps(item)).encode('utf-8')
    print(doc)
    break
# Out:
# b'{"_index": "hospital-index", "_id": "0"}\n{"Facility ID": "010001", "Facility Name": "SOUTHEAST ALABAMA MEDICAL CENTER", "Address": "1108 ROSS CLARK CIRCLE", "City": "DOTHAN", "State": "AL", "ZIP Code": 36301, "County Name": "HOUSTON", "Phone Number": "(334) 793-8701", "Measure ID": "HAI_1_CILOWER", "Measure Name": "Central Line Associated Bloodstream Infection (ICU + select Wards): Lower Confidence Limit", "Compared to National": "No Different than National Benchmark", "Score": "0.398", "Footnote": NaN, "Start Date": "10/01/2018", "End Date": "09/30/2019"}\n'

# %%
hospital_df.shape
# Out:
# (175824, 15)
